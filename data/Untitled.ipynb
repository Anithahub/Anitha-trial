# %%
import pymongo

# %%
import tweepy

# %%
from pymongo import MongoClient
client = MongoClient('mongo', username = 'dsi-melb', password = 'padlock')

# %%
client.list_database_names
# Out:
# <bound method MongoClient.list_database_names of MongoClient(host=['mongo:27017'], document_class=dict, tz_aware=False, connect=True)>

# %%
col_1 = client['my_db']['collection_1']

# %%
col_1.insert({'name': 'Alistair', 'location': 'at work'})
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-15-ebc7e34f0c92> in <module>
# ----> 1 col_1.insert({'name': 'Alistair', 'location': 'at work'})
#
# /opt/conda/lib/python3.6/site-packages/pymongo/collection.py in insert(self, doc_or_docs, manipulate, check_keys, continue_on_error, **kwargs)
#    3159             write_concern = WriteConcern(**kwargs)
#    3160         return self._insert(doc_or_docs, not continue_on_error,
# -> 3161                             check_keys, manipulate, write_concern)
#    3162
#    3163     def update(self, spec, document, upsert=False, manipulate=False,
#
# ...

# %%
col_1.find_one()
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-16-5f5a8c9c5994> in <module>
# ----> 1 col_1.find_one()
#
# /opt/conda/lib/python3.6/site-packages/pymongo/collection.py in find_one(self, filter, *args, **kwargs)
#    1260
#    1261         cursor = self.find(filter, *args, **kwargs)
# -> 1262         for result in cursor.limit(-1):
#    1263             return result
#    1264         return None
#
# /opt/conda/lib/python3.6/site-packages/pymongo/cursor.py in next(self)
#    1187         if self.__empty:
#    1188             raise StopIteration
# -> 1189         if len(self.__data) or self._refresh():
#    1190             if self.__manipulate:
#    1191                 _db = self.__collection.database
#
# /opt/conda/lib/python3.6/site-packages/pymongo/cursor.py in _refresh(self)
#    1102                                   self.__session,
# ...

# %%
for word in ['v f x g d j n u l', 'e n n v r f s p', 'w c f r h k d h s']:
    col_1.insert_one({k:v for k,v in enumerate('s k f b o w d o c k d'.split())})
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-14-2d0153aac893> in <module>
#       1
#       2 for word in ['v f x g d j n u l', 'e n n v r f s p', 'w c f r h k d h s']:
# ----> 3     col_1.insert_one({k:v for k,v in enumerate('s k f b o w d o c k d'.split())})
#
# /opt/conda/lib/python3.6/site-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation, session)
#     691                          write_concern=write_concern,
#     692                          bypass_doc_val=bypass_document_validation,
# --> 693                          session=session),
#     694             write_concern.acknowledged)
#     695
#
# /opt/conda/lib/python3.6/site-packages/pymongo/collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     605             return self._insert_one(
# ...

# %%
for i in col_1.find():
    print(i)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-17-d523244ee952> in <module>
# ----> 1 for i in col_1.find():
#       2     print(i)
#
# /opt/conda/lib/python3.6/site-packages/pymongo/cursor.py in next(self)
#    1187         if self.__empty:
#    1188             raise StopIteration
# -> 1189         if len(self.__data) or self._refresh():
#    1190             if self.__manipulate:
#    1191                 _db = self.__collection.database
#
# /opt/conda/lib/python3.6/site-packages/pymongo/cursor.py in _refresh(self)
#    1102                                   self.__session,
#    1103                                   self.__collection.database.client)
# -> 1104             self.__send_message(q)
#    1105         elif self.__id:  # Get More
#    1106             if self.__limit:
#
# ...
